# %%
my_list = ['abc','def','ghi']

# %%
def func(x):
    return x.upper()

# %%
for index,i in enumerate(my_list):
    my_list[index]=func(i)

# %%
my_list
# Out:
# ['ABC', 'DEF']

# %%
# map(function,sequence)
list(map(func,my_list))
# Out:
# ['ABC', 'DEF', 'GHI']
